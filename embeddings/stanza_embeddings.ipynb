# %%
import stanza

# %%
stanza.download('sl')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.0.0.json: 116kB [00:00, 2.82MB/s]
# 2020-04-19 21:09:52 INFO: Downloading default packages for language: sl (Slovenian)...
# Downloading http://nlp.stanford.edu/software/stanza/1.0.0/sl/default.zip: 100%|██████████| 223M/223M [01:07<00:00, 3.29MB/s]
# 2020-04-19 21:11:09 INFO: Finished downloading models and saved to /home/hanh/stanza_resources.

# %%
nlp = stanza.Pipeline('sl')
# Out:
# 2020-04-19 21:13:24 INFO: Loading these models for language: sl (Slovenian):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | ssj     |
# | pos       | ssj     |
# | lemma     | ssj     |
# | depparse  | ssj     |
# =======================
#
# 2020-04-19 21:13:24 INFO: Use device: cpu
# 2020-04-19 21:13:24 INFO: Loading: tokenize
# 2020-04-19 21:13:24 INFO: Loading: pos
# 2020-04-19 21:13:26 INFO: Loading: lemma
# 2020-04-19 21:13:26 INFO: Loading: depparse
# 2020-04-19 21:13:28 INFO: Done loading processors!

# %%
doc = nlp("Priročniki za učitelje ponujajo nasvete, kako čim bolje izkoristiti učbeniške vsebine, prinašajo tudi slikovno gradivo in dodatne vaje ter nasvete za realizacijo posameznih vsebin.")

# %%
print(doc)
print(doc.entities)
# Out:
# [
#   [
#     {
#       "id": "1",
#       "text": "Priročniki",
#       "lemma": "priročnik",
#       "upos": "NOUN",
#       "xpos": "Ncmpn",
#       "feats": "Case=Nom|Gender=Masc|Number=Plur",
#       "head": 4,
#       "deprel": "nsubj",
#       "misc": "start_char=0|end_char=10"
#     },
#     {
#       "id": "2",
#       "text": "za",
#       "lemma": "za",
#       "upos": "ADP",
#       "xpos": "Sa",
#       "feats": "Case=Acc",
#       "head": 3,
#       "deprel": "case",
#       "misc": "start_char=11|end_char=13"
#     },
#     {
#       "id": "3",
#       "text": "učitelje",
#       "lemma": "učitelj",
#       "upos": "NOUN",
#       "xpos": "Ncmpa",
#       "feats": "Case=Acc|Gender=Masc|Number=Plur",
#       "head": 1,
#       "deprel": "nmod",
#       "misc": "start_char=14|end_char=22"
#     },
#     {
#       "id": "4",
#       "text": "ponujajo",
#       "lemma": "ponujati",
#       "upos": "VERB",
#       "xpos": "Vmpr3p",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=23|end_char=31"
#     },
#     {
#       "id": "5",
#       "text": "nasvete",
#       "lemma": "nasvet",
#       "upos": "NOUN",
#       "xpos": "Ncmpa",
#       "feats": "Case=Acc|Gender=Masc|Number=Plur",
#       "head": 4,
#       "deprel": "obj",
#       "misc": "start_char=32|end_char=39"
#     },
#     {
#       "id": "6",
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "Z",
#       "head": 10,
#       "deprel": "punct",
#       "misc": "start_char=39|end_char=40"
#     },
#     {
#       "id": "7",
#       "text": "kako",
#       "lemma": "kako",
#       "upos": "ADV",
#       "xpos": "Rgp",
#       "feats": "Degree=Pos",
#       "head": 10,
#       "deprel": "advmod",
#       "misc": "start_char=41|end_char=45"
#     },
#     {
#       "id": "8",
#       "text": "čim",
#       "lemma": "čim",
#       "upos": "ADV",
#       "xpos": "Rgp",
#       "feats": "Degree=Pos",
#       "head": 9,
#       "deprel": "advmod",
#       "misc": "start_char=46|end_char=49"
#     },
#     {
#       "id": "9",
#       "text": "bolje",
#       "lemma": "dobro",
#       "upos": "ADV",
#       "xpos": "Rgc",
#       "feats": "Degree=Cmp",
#       "head": 10,
#       "deprel": "advmod",
#       "misc": "start_char=50|end_char=55"
#     },
#     {
#       "id": "10",
#       "text": "izkoristiti",
#       "lemma": "izkoristiti",
#       "upos": "VERB",
#       "xpos": "Vmen",
#       "feats": "Aspect=Perf|VerbForm=Inf",
#       "head": 5,
#       "deprel": "acl",
#       "misc": "start_char=56|end_char=67"
#     },
#     {
#       "id": "11",
#       "text": "učbeniške",
#       "lemma": "učbeniški",
#       "upos": "ADJ",
#       "xpos": "Agpfpa",
#       "feats": "Case=Acc|Degree=Pos|Gender=Fem|Number=Plur",
#       "head": 12,
#       "deprel": "amod",
#       "misc": "start_char=68|end_char=77"
#     },
#     {
#       "id": "12",
#       "text": "vsebine",
#       "lemma": "vsebina",
#       "upos": "NOUN",
#       "xpos": "Ncfpa",
#       "feats": "Case=Acc|Gender=Fem|Number=Plur",
#       "head": 10,
#       "deprel": "obj",
#       "misc": "start_char=78|end_char=85"
#     },
#     {
#       "id": "13",
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": "Z",
#       "head": 10,
#       "deprel": "punct",
#       "misc": "start_char=85|end_char=86"
#     },
#     {
#       "id": "14",
#       "text": "prinašajo",
#       "lemma": "prinašati",
#       "upos": "VERB",
#       "xpos": "Vmpr3p",
#       "feats": "Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 4,
#       "deprel": "parataxis",
#       "misc": "start_char=87|end_char=96"
#     },
#     {
#       "id": "15",
#       "text": "tudi",
#       "lemma": "tudi",
#       "upos": "PART",
#       "xpos": "Q",
#       "head": 14,
#       "deprel": "advmod",
#       "misc": "start_char=97|end_char=101"
#     },
#     {
#       "id": "16",
#       "text": "slikovno",
#       "lemma": "slikoven",
#       "upos": "ADJ",
#       "xpos": "Agpnsa",
#       "feats": "Case=Acc|Degree=Pos|Gender=Neut|Number=Sing",
#       "head": 17,
#       "deprel": "amod",
#       "misc": "start_char=102|end_char=110"
#     },
#     {
#       "id": "17",
#       "text": "gradivo",
#       "lemma": "gradivo",
#       "upos": "NOUN",
#       "xpos": "Ncnsa",
#       "feats": "Case=Acc|Gender=Neut|Number=Sing",
#       "head": 14,
#       "deprel": "obj",
#       "misc": "start_char=111|end_char=118"
#     },
#     {
#       "id": "18",
#       "text": "in",
#       "lemma": "in",
#       "upos": "CCONJ",
#       "xpos": "Cc",
#       "head": 20,
#       "deprel": "cc",
#       "misc": "start_char=119|end_char=121"
#     },
#     {
#       "id": "19",
#       "text": "dodatne",
#       "lemma": "dodaten",
#       "upos": "ADJ",
#       "xpos": "Agpfpa",
#       "feats": "Case=Acc|Degree=Pos|Gender=Fem|Number=Plur",
#       "head": 20,
#       "deprel": "amod",
#       "misc": "start_char=122|end_char=129"
#     },
#     {
#       "id": "20",
#       "text": "vaje",
#       "lemma": "vaja",
#       "upos": "NOUN",
#       "xpos": "Ncfpa",
#       "feats": "Case=Acc|Gender=Fem|Number=Plur",
#       "head": 17,
#       "deprel": "conj",
#       "misc": "start_char=130|end_char=134"
#     },
#     {
#       "id": "21",
#       "text": "ter",
#       "lemma": "ter",
#       "upos": "CCONJ",
#       "xpos": "Cc",
#       "head": 22,
#       "deprel": "cc",
#       "misc": "start_char=135|end_char=138"
#     },
#     {
#       "id": "22",
#       "text": "nasvete",
#       "lemma": "nasvet",
#       "upos": "NOUN",
#       "xpos": "Ncmpa",
#       "feats": "Case=Acc|Gender=Masc|Number=Plur",
#       "head": 17,
#       "deprel": "conj",
#       "misc": "start_char=139|end_char=146"
#     },
#     {
#       "id": "23",
#       "text": "za",
#       "lemma": "za",
#       "upos": "ADP",
#       "xpos": "Sa",
#       "feats": "Case=Acc",
#       "head": 24,
#       "deprel": "case",
#       "misc": "start_char=147|end_char=149"
#     },
#     {
#       "id": "24",
#       "text": "realizacijo",
#       "lemma": "realizacija",
#       "upos": "NOUN",
#       "xpos": "Ncfsa",
#       "feats": "Case=Acc|Gender=Fem|Number=Sing",
#       "head": 22,
#       "deprel": "nmod",
#       "misc": "start_char=150|end_char=161"
#     },
#     {
#       "id": "25",
#       "text": "posameznih",
#       "lemma": "posamezen",
#       "upos": "ADJ",
#       "xpos": "Agpfpg",
#       "feats": "Case=Gen|Degree=Pos|Gender=Fem|Number=Plur",
#       "head": 26,
#       "deprel": "amod",
#       "misc": "start_char=162|end_char=172"
#     },
#     {
#       "id": "26",
#       "text": "vsebin",
#       "lemma": "vsebina",
#       "upos": "NOUN",
#       "xpos": "Ncfpg",
#       "feats": "Case=Gen|Gender=Fem|Number=Plur",
#       "head": 24,
#       "deprel": "nmod",
#       "misc": "start_char=173|end_char=179"
#     },
#     {
#       "id": "27",
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": "Z",
#       "head": 4,
#       "deprel": "punct",
#       "misc": "start_char=179|end_char=180"
#     }
#   ]
# ]
# []
